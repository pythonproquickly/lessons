# %%
import random
from collections import deque
import collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "~/ws/client-files/andykmiles/src/andykmiles/yuy/tour750.csv"

# %%
import functools
import time
def timer(func):
    @functools.wraps(func)
    def wrapper_timer(*args, **kwargs):
        start_time = time.perf_counter()
        value = func(*args, **kwargs)
        end_time = time.perf_counter()
        run_time = end_time - start_time
        print(f"Ran {func.__name__!r} in {run_time:.4f} secs")
        return value

    return wrapper_timer

# %%
class Speedy:
    def __init__(self, func):
        self.func = func
        self.memo = {}

    def __call__(self, *args):
        if args not in self.memo:
            self.memo[args] = self.func(*args)
        return self.memo[args]

# %%
df = pd.read_csv(file, header = None)
df
# Out:
#              0            1            2            3            4    \
# 0       0.000000  5299.911323  3708.865860  2857.275799  1990.867548
# 1    5066.330150     0.000000   936.115460  2117.514323  2948.207290
# 2    4272.275283   929.147619     0.000000  1025.968076  2395.700794
# 3    3262.043821  2140.173990  1049.183153     0.000000  1452.459808
# 4    1887.307775  3357.160920  2844.591830  1354.838650     0.000000
# ..           ...          ...          ...          ...          ...
# 745  2709.780336  3072.387501  2192.484575  1345.216495  1604.398701
# 746  2885.444341  1906.513508  1426.256174   888.722900  1302.370956
# 747  1416.060246  4965.031876  3926.095173  3786.255624  2412.865920
# 748  1570.668271  6771.812186  4963.519931  4629.635511  3450.504633
# 749  1609.717085  5341.401968  4413.870051  4813.971046  3014.336541
#
#              5            6            7            8            9    ...  \
# 0     987.811005  1955.497685  1185.590928  3557.404225  3986.209111  ...
# 1    3636.644996  5708.066333  6049.078933  1667.535182  1474.081302  ...
# 2    3153.635207  5717.777707  5002.982405  1283.744781   642.218363  ...
# 3    2318.541976  3940.931624  4393.606172  1523.140631  1193.949165  ...
# 4     962.562887  3211.234139  3175.894240  2262.310919  2904.038499  ...
# ..           ...          ...          ...          ...          ...  ...
# 745  2211.044961  3312.164822  4332.878414  3234.134989  2255.304982  ...
# 746  2019.864008  4465.155062  3741.583673   931.220252  2276.305977  ...
# 747  2655.378122   511.725781  1351.471403  4253.389450  4960.628851  ...
# 748  2586.898113  1149.853771   967.382556  5013.199803  5662.580684  ...
# 749  2234.914614   629.450637   926.435888  5307.896033  5571.483955  ...
#
#              740          741          742          743          744  \
# 0    2344.627569  2522.154812  5429.627921  1203.471515  2555.206177
# 1    6155.655403  2473.715777   945.947807  5496.015509  8222.687748
# 2    4626.547282  1763.721460   532.919449  4981.125172  7650.378886
# 3    4194.608655   847.576798  1360.392675  3529.584720  4935.936661
# 4    3848.448598   923.628787  2725.984866  2164.293850  4864.184724
# ..           ...          ...          ...          ...          ...
# 745  3285.437823  1646.457948  2039.926159  2806.805404  5544.746435
# 746  4858.985771   293.132308  2206.683721  3804.897298  5533.019030
# 747   873.259406  3322.014229  4418.365126    70.581943  2283.900735
# 748  1584.760922  4862.781817  6371.031218  1176.562904  1394.589576
# 749  1227.170135  4267.618635  5468.724651   761.393908  1733.291768
#
#              745          746          747          748          749
# 0    2564.375229  3024.816048  1291.549110  1541.277119  1404.230723
# 1    3236.304703  2179.403636  5272.288169  6614.059496  6466.144049
# 2    2192.617925  1760.017710  4722.676042  5157.699688  5425.180500
# 3    1527.860055   792.593923  3497.570218  4901.161900  4491.408135
# 4    1338.767251  1172.094634  2132.693722  3640.690476  3054.231181
# ..           ...          ...          ...          ...          ...
# 745     0.000000  2082.621538  2321.574171  4344.699916  3136.632300
# 746  2019.745807     0.000000  3940.122905  4246.841633  3853.619012
# 747  2950.705645  3561.265704     0.000000  1490.712422   858.222457
# 748  4370.539227  4920.643592  1564.881466     0.000000   580.103275
# 749  3477.059523  4471.939931   779.356582   576.749181     0.000000
#
# [750 rows x 750 columns]

# %%
def getRandomPositions(size):

    individual = np.random.permutation(size)

    return list(individual)

# %%
def initialise(popSize, size):
    population = [getRandomPositions(size) for x in range(popSize)]

    return population

# %%
population = initialise(100, len(df))
#population

# %%
def calculateCost(df, individual):
    # function written by teammate, check if the last distance was added?

    accumulated_dist = 0
    for i in range(len(individual)):
        dist = df[individual[i]][individual[(i + 1) % len(individual)]]
        accumulated_dist += dist

    return accumulated_dist

# %%
def select_parent(df, population):
    # use k-tournament selection to find parents
        
    parents =random.choices(population, k=7) #k=3 #change from 3 to 7 increased the result a lot
    costParents = [calculateCost(df, x) for x in parents]
    parent_indx = costParents.index(min(costParents))
    selected_parent = parents[parent_indx]

    return selected_parent

# %%
def order_crossover(parent1, parent2):

    size = len(parent1)
    positions = random.sample(range(0,size), 2)

    pos1 = min(positions[0], positions[1])   #random.randint(0, 9)
    pos2 = max(positions[0], positions[1])   #random.randint(0, 9)

    pos = [pos1, pos2]

    ### Copy the part from the parent1
    parent1_part = parent1[pos[0]:pos[1] + 1]

    ### Find the parent2 parts
    i_list = collections.deque(range(len(parent1)))
    i_list.rotate(-(pos[1] + 1))

    parent2_part = []

    for i in i_list:
        if parent2[i] not in parent1_part:
            parent2_part.append(parent2[i])
    return parent2_part[len(parent1) - pos[1] - 1:] + parent1_part + parent2_part[:len(parent1) - pos[1] - 1]

# %%
parent1 = select_parent(df, population)
parent2 = select_parent(df, population)
child = order_crossover(parent1, parent2)

# %%
def inversion_mutation(candidate):

    pos = random.sample(range(len(candidate)), 2)
    pos.sort()

    inversed_part = candidate[pos[0]:pos[1] + 1]
    inversed_part.reverse()
    new_candidate = candidate[:pos[0]] + inversed_part + candidate[pos[1] + 1:]
    return new_candidate

# %%
@timer
def get_new_population(df, population):    
    mutation_rate = 0.1

    off_springs = []
    
    ivals = tuple(range(len(population)//2))
    
    
    parentOneList = tuple([select_parent(df, population) for i in ivals])
    parentTwoList = tuple([select_parent(df, population) for i in ivals])


    for i in ivals:
        p1 = parentOneList[i]
        p2 = parentOneList[i]
        offspringOne = order_crossover(p1, p2)
        offspringTwo = order_crossover(p2, p1)
  
        # apply mutation rate with 0.1
        if random.uniform(0, 1) < mutation_rate:
            offspringOne = inversion_mutation(offspringOne)
        if random.uniform(0, 1) < mutation_rate:
            offspringTwo = inversion_mutation(offspringOne)
            
        off_springs.append(offspringOne)
        off_springs.append(offspringTwo)
                
    costs = np.array([calculateCost(df, ind) for ind in off_springs])
    return off_springs, costs

# %%
new_population, costs = get_new_population(df, population)
# Out:
# Ran 'get_new_population' in 3.4202 secs

# %%
number_its = 50
avg = []
minimum = []
for i in range(number_its):
    population, costs = get_new_population(df, population)
    avg.append(np.mean(costs))
    minimum.append(np.min(costs))
# Out:
# Ran 'get_new_population' in 3.0404 secs
# Ran 'get_new_population' in 3.2053 secs
# Ran 'get_new_population' in 3.0498 secs
# Ran 'get_new_population' in 2.8523 secs
# Ran 'get_new_population' in 3.1143 secs
# Ran 'get_new_population' in 3.1833 secs
# Ran 'get_new_population' in 3.2783 secs
# Ran 'get_new_population' in 2.8803 secs
# Ran 'get_new_population' in 2.9342 secs
# Ran 'get_new_population' in 2.9263 secs
# Ran 'get_new_population' in 2.8918 secs
# Ran 'get_new_population' in 2.8853 secs
# Ran 'get_new_population' in 2.7941 secs
# Ran 'get_new_population' in 2.8647 secs
# Ran 'get_new_population' in 2.9822 secs
# Ran 'get_new_population' in 3.3582 secs
# Ran 'get_new_population' in 3.2441 secs
# Ran 'get_new_population' in 2.9368 secs
# Ran 'get_new_population' in 2.9569 secs
# Ran 'get_new_population' in 3.0388 secs
# Ran 'get_new_population' in 3.1052 secs
# Ran 'get_new_population' in 2.9403 secs
# Ran 'get_new_population' in 2.9988 secs
# Ran 'get_new_population' in 2.8952 secs
# Ran 'get_new_population' in 2.7930 secs
# Ran 'get_new_population' in 2.9905 secs
# Ran 'get_new_population' in 2.8434 secs
# Ran 'get_new_population' in 3.2515 secs
# Ran 'get_new_population' in 3.0530 secs
# Ran 'get_new_population' in 3.2401 secs
# Ran 'get_new_population' in 2.9103 secs
# Ran 'get_new_population' in 2.8321 secs
# Ran 'get_new_population' in 2.8519 secs
# Ran 'get_new_population' in 2.8532 secs
# Ran 'get_new_population' in 2.7987 secs
# Ran 'get_new_population' in 2.8300 secs
# Ran 'get_new_population' in 3.0423 secs
# Ran 'get_new_population' in 2.9011 secs
# Ran 'get_new_population' in 2.8961 secs
# Ran 'get_new_population' in 2.8218 secs
# Ran 'get_new_population' in 2.7345 secs
# Ran 'get_new_population' in 2.8271 secs
# Ran 'get_new_population' in 2.9290 secs
# Ran 'get_new_population' in 2.8809 secs
# Ran 'get_new_population' in 3.1649 secs
# Ran 'get_new_population' in 3.1607 secs
# Ran 'get_new_population' in 3.1144 secs
# Ran 'get_new_population' in 3.0561 secs
# Ran 'get_new_population' in 3.0440 secs
# Ran 'get_new_population' in 2.8814 secs

# %%
plt.plot(range(len(avg)), avg)
plt.plot(range(len(minimum)), minimum)

# %%
def generate_smart_individual(df, individual):
    df_copy = df.copy()

    smart_positions = []

    positions = random.sample(range(0,size), 2)
    pos1 = min(positions[0], positions[1])   #random.randint(0, 9)
    pos2 = max(positions[0], positions[1])   #random.randint(0, 9)

    pos = [pos1, pos2]
    segm = individual[pos1, pos2]
    
    seg_size = pos2-pos1 + 1
    k = 10 
    for i in range(size-1):
        smart_positions.append(individual[pos1])

    # choose 3 near neighbors based on distance
        choose_nn = list(df_copy[start].sort_values().index)[1:k]
    # randomly choose one among 3
        next_stop = random.choice(choose_nn)
    # delete the row that was the start
        df_copy = df_copy.drop(start)
        start = next_stop # now setting the start as next stop

# add index of last number
    smart_positions.append(int(df_copy.reset_index()["index"]))
    return smart_positions

# %%
smart_individuals = generate_smart_individual(df, size)
