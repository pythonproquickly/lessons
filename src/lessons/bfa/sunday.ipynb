# %% [markdown]
# Capstone Project Dr. Dorothy Udo Healthcare Utilization Rate for Mexico-Border States July 12, 2022
#
# Introduction
#
# The goal of this capstone project is to use exploratory data analysis(EDA) and a supervised machine learning algorithm to gain insight at the healthcare utilization rate around the border and non-border states of the United States of America. This study aims to draw a conclusion that the cost of healtcare around the border state is not higher than the non-border states
#
# Problem Statement
#
# It is commonly assumed by many people in the debate over immigration that unauthorized immigrants rely on emergency room as their primary source of health care; because the Emergency Medical Treatment and Labor Act of 1986 allows access to health regardless of individual ability to pay. According to abcnews.go.com, “slightly over half of Americans(52%) believe that immigrants are a financial burden on the U.S. healthcare system, and two thirds believe that undocumented immigrants should not be eligible for social services provided by state and local governments.”
#
# Background
#
# According to 2021 U.S. Census Bureau data, just over 8 million people reside in the U.S.-Mexico border region, with 356,133 living in nonmetro counties. The resident population in the border region has experienced a population growth rate of 6.5% between 2010 and 2021, with much of the growth occurring in the region's 13 metropolitan counties. Between 2010 and 2021, the region's rural counties saw a 9.6% population decline, on average, with only 5 rural counties seeing a rise in population over the 11-year period. The shifting population, along with the continual movement of individuals across the border, places numerous burdens on the economic, social, and health infrastructure of the region, taxing communities already faced with ongoing health and socioeconomic challenges. In the United States, health care can be difficult to afford. But for the thousands of migrants currently showing up at the U.S.-Mexico border, it’s nearly impossible. In recent months, the number of migrants entering the United States has increased significantly. the cost of providing health care to migrants and transferring them to receive care at other medical facilities has not come cheap. Contrary to these claims, researchers at Harvard Medical School and Tufts University assessed all peer-reviewed studies since 2000 related to healthcare costs by immigrants in the United States. The authors found that the overall healthcare costs by immigrants were one-half to two-thirds those of people born in the U.S. The report also found that immigrants make up 12% of the population, but only account for 8.6% of total U.S. healthcare spending. As a result, health expenditures were particularly low for undocumented immigrants.
#
# Motivation
#
# The project is inspired by the unending immigration debate and recent public policy debates in the US. These policies have focused on decreasing unauthorized immigration from Mexico, and made it harder for legal immigrants to become permanent residents and citizens if they have used a range of public welfare programs including healthcare. Also, some policy makers argue that unauthorized immigrants are a net drain on federal and state benefits programs. They believe that these immigration policies will increase healthcare expenditures by way of its negative health impact on immigrant children and families.
#
# Proposed Solution In this supervised learning machine learning project, I will determine whether the states that are around the Mexico border have a higher healthcare utilization rate when compared to the non -border states.
#
# Data source
#
# This dataset was obtained from the Healthcare Cost and Utilization Project (HCUP), a family of databases, software tools and related products developed through a Federal-State-Industry partnership and sponsored by AHRQ. HCUP databases are derived from administrative data and contain encounter-level, clinical and nonclinical information including all-listed diagnoses and procedures, discharge status, patient demographics, and charges for all patients, regardless of payer (e.g., Medicare, Medicaid, private insurance, uninsured), beginning in 1988. These databases enable research on a broad range of health policy issues, including cost and quality of health services, medical practice patterns, access to health care programs, and outcomes of treatments at the national, State, and local market levels.
#
# Implementation This dataset was obtained from the Agency for Healthcare Research and Quality via open source request from HCUPnet. After the request was approved, the dataset was extracted in csv format and stored in my computer C-drive. The uncleaned dataset was imported into Jupyter notebook . The dataset contained 16 observations and 12 features. Data type was mostly floats and one character. Missing values were absent in the dataset. Next, the dataset was wrangled and preprocessed in the following steps:
#
# Normalization of the column names by the removal of unwanted and conversion of the first letters to upper case, data was reshaped by converting the categorical data into numbers.
# The implementation process was split into two main stages:
#
# The classifier training stage
#
# The application development stage
# During the first stage, the classifier was trained on the preprocessed training data. This was done in a Jupyter notebook. This step involved:
#
#  Loading both the training and validation sets into memory
#  Preprocessing them as described in the previous section
#  Implementing helper functions by drawing a random sample from the training/validation data
#
# Description of Data Analysis
#
# Data analysis will consist of the following steps: Data exploration with descriptive statistics and data visualization. Conducted univariate visualization of each individual variable using box and whisker plots and a multivariate plot to view the interactions between the variables. Also plotted a histogram of each input variable to get an idea of the distribution, and a confusion matrix to evaluate the accuracy of the classification model.
#
# Building Model and Evaluating Algorithms
#
# Six algorithms were compared in order to identify the most appropriate approach:
#
# LR: 0.955090 (0.020423) LDA: 0.950110 (0.016695) KNN: 0.982521 (0.013164) CART: 0.849552 (0.024146) NB: 0.812183 (0.031981) SVM: 0.310944 (0.027463)
#
#  Created models of the data and estimated their accuracy based on the following: LogisticRegression(LR), LinearDiscriminantAnalysis(LDA), KNeighborsClassifier(KNN), DecisionTreeClassifier(CART), GaussianNB(NB) and Support Vector Classifier (SVC)
#  Cross validated model by splitting the data into training, test and validation set based on the ratio of 70%, 30 respectively  Set-up the test harness to use a 10-fold cross validation  Selected KNN as the best model based on the result below
#
# I chose to use a rlinear regression analysis model because my dataset were mostly continous(integer/floats). The  performance of this model was reported as errors, since the goal is determine how close the the prediction of "mean cost of stay" is to the actual values.
#
# Linear Regression uses the linear model to assume a linear relationship between input variables (independent variables ‘x’) and output variable (dependent variable-’y’) such that ‘y’ can be calculated from a linear combination of input variables (x). Some of the applications of Linear Regression in Healthcare include: predicting hospital length of stay, predictive modeling in healthcare costs and predicting medical expenses using insurance data.
#
# How to determine how well the model is doing: The metric that is commonly used to predict is called the coefficient of determination or R-squared. It is the percentage of variance of the target variable that is predicted by the features. The goal is achiev an R-squared close to 1 in order to prove that the model is very predictive.
#
#
#
#
#
#
# Architectural Diagram of Proposed Project
#
#
#
# Result and Discussion
#
# #Insights: Border Region
#
# #TexasBorder Region had the lowest Mean_Cost_Per_Stay
# #ArizonaBorderRegion had the lowest Total_Discharges
# #NewMexicoBorderRegion had the highest Total_Discharges and highest "Mean_Length_Stay_Days
# #CaliforniaBorderRegion had the highest Mean_Cost_Per_Stay and the lowest Mean_Length_Stay_Days.
#
#
# ##Insights: Non-Border Region:
#
# #ArizonaNon-BorderRegion had the highest Total_Discharges
# #TexasNon-BorderRegion had the highest Mean_Length_Stay_Days
# #CaliforniaNon-BorderRegion had the highest Mean_Cost_Per_Stay and the lowest Mean_Length_Stay_Days
# #NewMexicoNon-BorderRegion had the lowest Total_Discharges and Mean_Cost_Per_Stay
#
# Accuracy Evaluation:MAE 35518.05968757063, MSE 1778404146.3989406, RMSE 42171.12929954498, R_Squared= -164.3288470309463
#
# Predicted values for "Total number of discharges: and "Mean length of stay, days" are  -30257.60326424, 2443.92420345  28556.56897649]
#
#
#
# limitation
#
#
#
# Take away and Outcome and of this project experience
#
# Understanding  Data Science Life Cycle  Univariate and Bivariate analysis  Data visualizations using various charts and gaining insights from visualization  How to plot confusion matrix for visualizing the result  Cleaning and preparing the data for modelling  Standard Scaling and normalizing the dataset.  The reason behind Train and Test split for model validation  Selecting the best model and making predictions  Understanding how to apply the following algorithms: LogisticRegression(LR), LinearDiscriminantAnalysis(LDA), KNeighborsClassifier(KNN), DecisionTreeClassifier(CART), GaussianNB(NB) and Support Vector Classifier (SVC)
#
#
#
# Conclusion In progress
#
#
#
#
#
# References
#
# https://www.ahrq.gov/research/findings/nhqrdr/2014chartbooks/hispanichealth/part4.html https://cronkitenews.azpbs.org/2019/04/30/migrant-medical-cost/ https://abcnews.go.com/Health/immigrants-cost-healthcare-system-us-born-americans-study/story?id=57128979. https://scikit-learn.org/stable/modules/linear_model.html https://stackabuse.com/random-forest-algorithm-with-python-and-scikit-learn/ https://machinelearningmastery.com/machine-learning-in-python-step-by-step/ https://realpython.com/knn-python/ https://kdpsingh.lab.medicine.umich.edu/lhs-610 https://www.analyticsvidhya.com/blog/2021/08/how-to-perform-exploratory-data-analysis-a-guide-for-beginners/ https://hcupnet.ahrq.gov/#
# http://bielism.blogspot.com/2013/12/hcup-and-python-pt-i-background.html
# http://bielism.blogspot.com/2013/12/hcup-and-python-pt-4-reading-in-data.html
# http://bielism.blogspot.com/2013/12/hcup-and-python-pt-5-nulls-and-pre.html
# https://pypi.org/project/PyHCUP/
# https://www.kaggle.com/code/residentmario/bivariate-plotting-with-pandas/notebook
# https://www.formpl.us/blog/categorical-data
# https://machinelearningmastery.com/make-predictions-scikit-learn/

# %%
#Importing libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import median_absolute_error, r2_score

# %%
#Loading file into Python
border_states = pd.read_csv('Border_Regions.csv')

# %%
##Viewing the first 5 rows 
border_states.head()
# Out:
#                          Unnamed: 0  Total number of discharges  \
# 0                          US Total                 373814.9291
# 1  Total for All Four Border States                  68333.0000
# 2                     Arizona Total                   5639.0000
# 3                  California Total                  32696.0000
# 4                  New Mexico Total                   1760.0000
#
#    Rate of discharges per 100,000 population  \
# 0                                 114.970710
# 1                                  88.838305
# 2                                  86.573679
# 3                                  82.727365
# 4                                  85.858810
#
#    Age/sex adjusted rate of discharges per 100,000 population  \
# 0                                         114.970710
# 1                                          87.593836
# 2                                          75.032602
# 3                                          80.517477
# ...

# %% [raw]
# border_states.rename(columns={'Unnamed: 0':'State'}, inplace=True )
# border_states['is_border'] = border_states['State']
# border_states = border_states[ ['is_border'] + [ col for col in border_states.columns if col != 'is_border' ]]
# no_totals = border_states[['Total' not in each for each in border_states['State']]]
# no_totals['State'] = no_totals['State'].apply(lambda x: x.replace("Border Region"))
# no_totals['State'] = no_totals['State'].apply(lambda x: x.replace("Non"))

# %%
border_states.rename(columns={'Unnamed: 0':'State'}, inplace=True )
border_states['is_border'] = border_states['State']
border_states = border_states[ ['is_border'] + [ col for col in border_states.columns if col != 'is_border' ]]
no_totals = border_states[['Total' not in each for each in border_states['State']]]
no_totals['State'] = no_totals['State'].apply(lambda x: x.replace("Border Region", ""))
no_totals['State'] = no_totals['State'].apply(lambda x: x.replace("Non-", ""))
for border_state in ['Arizona', 'California', 'New Mexico', 'Texas']:
    no_totals['is_border'] = no_totals['is_border'].apply(lambda x: x.replace(border_state, ""))
# Out:
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\1307038255.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_totals['State'] = no_totals['State'].apply(lambda x: x.replace("Border Region", ""))
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\1307038255.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_totals['State'] = no_totals['State'].apply(lambda x: x.replace("Non-", ""))
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\1307038255.py:8: SettingWithCopyWarning:
# ...

# %%
no_totals
# Out:
#              is_border        State  Total number of discharges  \
# 7        Border Region     Arizona                       1252.0
# 8        Border Region  California                       2437.0
# 9        Border Region  New Mexico                        426.0
# 10       Border Region       Texas                       3298.0
# 12   Non-Border Region     Arizona                       4387.0
# 13   Non-Border Region  California                      30259.0
# 14   Non-Border Region  New Mexico                       1334.0
# 15   Non-Border Region       Texas                      24940.0
#
#     Rate of discharges per 100,000 population  \
# 7                                   90.047714
# 8                                   69.333685
# 9                                  122.977795
# 10                                 117.776376
# 12                                  78.656947
# 13                                  83.643140
# 14                                  76.637861
# ...

# %%
#dimension of the DataFrame(Rows and columns view)
no_totals.shape
# Out:
# (8, 13)

# %%
##description of numeric data features
no_totals.describe()

#Insight: The average Rate of discharges per 100,000 population= 92.619577, and the maximum Rate of discharges per 100,000 population =122.977795
#the average cost per stay= $25330.875701, while the maximum cost per stay= 31180.623320 
#The average length of stay in days= 4.529865, while the maximum length of stay in days = 5.035211


#Insight for dataset distribution: Noticeably, the mean values for some of the colums are less than the median values. 
#This means that the distribution for those columns are negatively skewed, because most of the values lie at the lower tail of the distribution.
# Out:
#        Total number of discharges  Rate of discharges per 100,000 population  \
# count                    8.000000                                   8.000000
# mean                  8541.625000                                  92.171277
# std                  11913.533108                                  19.511541
# min                    426.000000                                  69.333685
# 25%                   1313.500000                                  78.152176
# 50%                   2867.500000                                  86.845427
# 75%                   9525.250000                                 103.166616
# max                  30259.000000                                 122.977795
#
#        Age/sex adjusted rate of discharges per 100,000 population  \
# count                                           8.000000
# mean                                           88.322933
# std                                            24.947810
# ...

# %%
#Descriptive statistics of the feature "Total number of discharges"
no_totals['Total number of discharges'].describe()
# Out:
# count        8.000000
# mean      8541.625000
# std      11913.533108
# min        426.000000
# 25%       1313.500000
# 50%       2867.500000
# 75%       9525.250000
# max      30259.000000
# Name: Total number of discharges, dtype: float64

# %%
#Boxplot to visualize the descriptive statistics of a single variable Total number of discharges

sns.boxplot(no_totals["Total number of discharges"],color='darkorange')
# Out:
# C:\Users\DOROTHY\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total number of discharges'>

# %%
#dataframe summary
no_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 7 to 15
# Data columns (total 13 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   is_border                                                         8 non-null      object
#  1   State                                                             8 non-null      object
#  2   Total number of discharges                                        8 non-null      float64
#  3   Rate of discharges per 100,000 population                         8 non-null      float64
#  4   Age/sex adjusted rate of discharges per 100,000 population        8 non-null      float64
#  5   Mean length of stay, days                                         8 non-null      float64
#  6   Aggregate number of days in the hospital                          8 non-null      float64
# ...

# %%
#Viewing missing values in the dataset: this dataset has no null value for all columns
no_totals.isnull().sum()
# Out:
# is_border                                                           0
# State                                                               0
# Total number of discharges                                          0
# Rate of discharges per 100,000 population                           0
# Age/sex adjusted rate of discharges per 100,000 population          0
# Mean length of stay, days                                           0
# Aggregate number of days in the hospital                            0
# Number of inpatient days per 100,000 population                     0
# Age/sex adjusted number of inpatient days per 100,000 population    0
# Mean cost per stay, $                                               0
# Aggregate costs for all hospital stays, $                           0
# Costs for inpatient stays per capita, $                             0
# Age/sex adjusted costs for inpatient stays per capita, $            0
# dtype: int64

# %%
#Using a heatmap to view the amount of data that is missing from the attributes
sns.heatmap(no_totals.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#Bivariate plot of "is_border"(Border and Non-border states) Vs "Mean cost per stay, $"
pd.pivot_table(no_totals.reset_index(), 
index='is_border', columns='State', values='Mean cost per stay, $').plot.bar()
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.title('is_border Vs Mean cost per stay, $')


#Bivariate plot of "is_border"(Border and Non-border states) Vs "Mean length of stay, days"
pd.pivot_table(no_totals.reset_index(), 
index='is_border', columns='State', values='Mean length of stay, days').plot.bar()
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.title('is_border Vs Mean length of stay, days')


#Bivariate plot of "is_border"(Border and Non-border states) Vs "Total number of discharges"
pd.pivot_table(no_totals.reset_index(), 
index='is_border', columns='State', values='Total number of discharges').plot.bar()
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.title('is_border Vs Total number of discharges')



#Insights: Border Region 

#TexasBorder Region had the lowest Mean_Cost_Per_Stay
#ArizonaBorderRegion had the lowest Total_Discharges
#NewMexicoBorderRegion had the highest Total_Discharges and highest "Mean_Length_Stay_Days
#CaliforniaBorderRegion had the highest Mean_Cost_Per_Stay and the lowest Mean_Length_Stay_Days.


##Insights: Non-Border Region:

#ArizonaNon-BorderRegion had the highest Total_Discharges
#TexasNon-BorderRegion had the highest Mean_Length_Stay_Days
#CaliforniaNon-BorderRegion had the highest Mean_Cost_Per_Stay and the lowest Mean_Length_Stay_Days
#NewMexicoNon-BorderRegion had the lowest Total_Discharges and Mean_Cost_Per_Stay
# Out:
# Text(0.5, 1.0, 'is_border Vs Total number of discharges')

# %%
#Boxplot of "is_border"(Border and Non-border states) Vs "Mean length of stay, days"
sns.boxplot(x="is_border", y="Mean length of stay, days", hue='is_border', data = no_totals,)
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.title('is_border Vs Mean length of stay, days')

# Set axes limit
plt.ylim(0 , 5)
plt.show()

# %%
#scatter plot of is_border (Border and Non-border states) Vs Total number of discharges

sns.scatterplot( x='is_border', y='Total number of discharges', alpha = .7, hue='is_border', data = no_totals,)
plt.title('is_border Vs Total number of discharges')
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.xticks(rotation=90)
plt.legend(['is_border'],loc='upper right')

#Insight: The scatter plot below is indicating that more people were discharged from the non border states compared to the border states

# %%
#Univariate plots 

#vertical histogram of Total number of discharges
#Insight:From the histogram plot, I would infer that the Total number of discharges ranges from 5000 to 30000.
sns.histplot(no_totals["Total number of discharges"],color='darkorange')
# Out:
# <AxesSubplot:xlabel='Total number of discharges', ylabel='Count'>

# %%
#vertical histogram of Total number of discharges: 
#Insight:From the histogram plot, I would infer that the Mean length of stay, days ranges from 4 to 5.
sns.histplot(no_totals["Mean length of stay, days"],color='blue')
# Out:
# <AxesSubplot:xlabel='Mean length of stay, days', ylabel='Count'>

# %%
#vertical histogram of Total number of discharges
#Insight:From the histogram plot, I would infer that the Mean cost per stay, $ ranges from $20000 to 30000.
sns.histplot(no_totals["Mean cost per stay, $"],color='yellow')
# Out:
# <AxesSubplot:xlabel='Mean cost per stay, $', ylabel='Count'>

# %%
#line Distplot of the Mean cost per stay, $
sns.distplot(no_totals["Mean cost per stay, $"],color='darkorange')


#Insight: The Mean cost per stay, $ is evenly distributed
# Out:
# C:\Users\DOROTHY\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Mean cost per stay, $', ylabel='Density'>

# %%
#scatter plot of Mean cost per stay, $ Vs Mean length of stay, days
sns.scatterplot(no_totals["Mean length of stay, days"],no_totals['Mean cost per stay, $'],color='blue') 

#Insight: The scatter plot below shows a negative correlation between the duration of stay at the hospital and the cost of stay. The longer the stay, the lower the cost. I'm assuming this the negative correlation is caused by mean values of the datasets instead of individual values.
# Out:
# C:\Users\DOROTHY\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Mean length of stay, days', ylabel='Mean cost per stay, $'>

# %%
#scatter plot of Total number of discharges Vs Mean cost per stay, $'
sns.scatterplot( x='Total number of discharges', y='Mean cost per stay, $', alpha = .7, hue='is_border', data=no_totals,)

#Insight: There is no linear relationship between the target variable(Mean cost per stay, $') and the feature(Total number of discharges). This scatter plot is indicating that less amount of people were discharged from the hospital as the cost stay was going higher
# Out:
# <AxesSubplot:xlabel='Total number of discharges', ylabel='Mean cost per stay, $'>

# %%
#finding the Skewness and Kurtosis of the above graph: Skewness is a measure of the symmetry in a distribution. A symmetrical data set will have a skewness equal to 0. So, a normal distribution will have a skewness of 0. Skewness essentially measures the relative size of the two tails.
print("skewness:%f" %no_totals['Mean cost per stay, $'].skew())
print("skewness:%f" %no_totals['Mean cost per stay, $'].kurt())
# Out:
# skewness:0.170928
# skewness:-0.387056

# %%
#Machine learning

#Finding the unique value of the catgorical features "State" and "is_border"
no_totals['State'].value_counts(), no_totals['is_border'].value_counts()
# Out:
# (0    2
#  1    2
#  2    2
#  3    2
#  Name: State, dtype: int64,
#  0    4
#  1    4
#  Name: is_border, dtype: int64)

# %%
#Coverting the data types from object to category
no_totals['is_border'] = no_totals['is_border'].astype('category').cat.codes
no_totals['State'] = no_totals['State'].astype('category').cat.codes
# Out:
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\1096014787.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_totals['is_border'] = no_totals['is_border'].astype('category').cat.codes
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\1096014787.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_totals['State'] = no_totals['State'].astype('category').cat.codes

# %%
#transforming non-numerical variables to numerical labels.
from sklearn.preprocessing import LabelEncoder
no_totals['is_border'].head()
no_totals['State'].head()
# Out:
# 7     0
# 8     1
# 9     2
# 10    3
# 12    0
# Name: State, dtype: int32

# %%
le = LabelEncoder()
no_totals['is_border'] = le.fit_transform(no_totals['is_border'])

le = LabelEncoder()
no_totals['State'] = le.fit_transform(no_totals['State'])

le.classes_
# Out:
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\2079015968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_totals['is_border'] = le.fit_transform(no_totals['is_border'])
# C:\Users\DOROTHY\AppData\Local\Temp\ipykernel_18272\2079015968.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_totals['State'] = le.fit_transform(no_totals['State'])
# array([0, 1, 2, 3], dtype=int32)

# %%
X = no_totals.iloc[:, 0:4].values
y = no_totals.iloc[:, 4].values

# %%
#Splitting data into training and testing sets:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
#Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Step1: Training a Linear Regression Model: Here, I'll apply a linear regression on the particular dataset and after that, I'll study each evaluation metric and check it on the Linear Regression model.
#Splitting our data into ‘X’ array that contains the features and a ‘y’ array with the target variable

X = no_totals[['is_border', 'Total number of discharges', 'Mean length of stay, days']]# predicted variables
y = no_totals['Mean cost per stay, $']

# %%
X.head()
# Out:
#     is_border  Total number of discharges  Mean length of stay, days
# 7           0                      1252.0                   1.539475
# 8           0                      2437.0                   1.449306
# 9           0                       426.0                   1.616455
# 10          0                      3298.0                   1.604270
# 12          1                      4387.0                   1.493357

# %%
y.head()
# Out:
# 7     24651.58359
# 8     31180.62332
# 9     26289.94718
# 10    19488.46604
# 12    25642.61381
# Name: Mean cost per stay, $, dtype: float64

# %%
#Using logarithmic (np.log1p) and an exponential function (np.expm1) to transform the target variable() before training a linear regression model and using it for prediction.
X, y = make_regression(n_samples=10000, noise=100, random_state=42)
y = np.expm1((y + abs(y.min())) / 200)
y_trans = np.log1p(y)

# %%
#plotting the distribution of the transformed target variable

f, (ax0, ax1) = plt.subplots(1, 2)

ax0.hist(y, bins=100, density=True)
ax0.set_xlim([0, 2000])
ax0.set_ylabel("Probability")
ax0.set_xlabel("Mean cost per stay, $")


ax1.hist(y_trans, bins=100, density=True)
ax1.set_ylabel("Probability")
ax1.set_xlabel("Logarithm of Mean cost per stay, $")


f.suptitle("Mean cost per stay, $", y=0.06, x=0.53)
f.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)



#Assumption #2: The target and the feature variables have to be normally distributed
#In the figure below, the left plot shows the target variable before using a logarithmic transformation. aAs you can see, it is terribly left skewed. The right plot, shows how applying this transformation results in a remarkably normal distribution

# %%
#Assumption #3: Is there little to no multicollinearity among the features?

#viewing the correlation between different features
plt.figure(figsize=(10,10))
sns.heatmap(no_totals.corr(),cbar=True,annot=True,cmap='Blues')


#Insight: Multicollinearity is when the features are highly correlated with each other. Below, we see a heat map where the darker colors indicate strong positive correlations and the lighter shades represents negative correlation.
#Ideally, we would see only light colors everywhere else except the diagonal line across the middle, as obviously a variable will be perfectly correlated with itself.
#This can lead to imprecise regression coefficients or worse, changes in sign for the same features in different samples, which makes it difficult to reliably extract meaning out of those coefficients.
#The way to go about solving this is to remove uncorrelated features until there is no longer any collinearity
# Out:
# <AxesSubplot:>

# %%
#Step 2: splitting the dataset(Border_Regions.csv) into a training set and a testing set

#importing train_test_split model
from sklearn.model_selection import train_test_split

#generating regression dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
#Checking the number of records for both training dataset and testing dataset
len(X_test), len(X_train), len(no_totals)
# Out:
# (4000, 6000, 8)

# %%
#Step 3: Training and Testing the model by evaluating the model using a Linear regression
# importing the model
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# Fit linear model by passing training dataset
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Step 4: Predicting the Model: 
# Predicting the target variable for test datset: Here, I'll pass ‘X_test’ to the model to predict the ‘y_test’
predictions = model.predict(X_test)

# %%
for i in range(len(y_test)):
    print('%s => %d (expected %s)' % (X[i].tolist(), Y_predicted[i], y_test[i].tolist()))
# Out:
# [0.5578437435593815, -1.724488668316241, -1.167184416003872, 2.224392631147198, -1.2469636989162949, -0.23574026772537868, -1.443181620062757, -1.3849781367554532, 0.4573064542739106, -2.1029864392378887, 1.6279196354479482, -0.20272543734442497, 0.8803029522859216, -1.3607834733201392, 1.232871542564588, -0.8059890929456427, -0.8594007902598229, 0.04156161724209905, -1.489333617950285, -1.3686153510813006, 0.09858233713126703, -1.5891334675228708, 0.10693190288824854, 0.7978578646219977, 1.0827105335315388, -0.5057960070312287, 0.1794847517437893, -0.09546866731292573, 0.46769594451281354, 2.382618723656168, 0.5233745279224273, 1.0473471869423954, -0.9334851116617301, 0.5939434942883154, -1.5587539359346088, -0.5890629558189012, -0.4472638052515313, -0.0390885879258319, -0.9177580421966668, -1.922051403445587, -1.2525854485422963, -0.35548231033477723, -0.07028400666843887, -1.2160927038964155, -1.2020784485454163, 0.38159317645447255, 0.5951144978871618, -0.909986374180291, -1.2523
# ...

# %%
#Step 5: Comparing the results: The ‘prediction’ results will be compard with the actual results by plotting a graph

import matplotlib.pyplot as plt
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

#Insight:There is no linear relationship between the target variable and the feature. 
#To rectify this situation, we could do some feature engineering. One option is to do a logarithmic transformation of both the feature and the target.
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
plt.plot(y_test, color = 'red', label = 'Test data')
plt.plot(Y_predicted, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %%
#function to derive relative_absolute_error, mean_squared_error,root_mean_squared_error

def relative_absolute_error(true, pred):
    true_mean = np.mean(true)
    squared_error_num = np.sum(np.abs(true - pred))
    squared_error_den = np.sum(np.abs(true - true_mean))
    rae_loss = squared_error_num / squared_error_den
    return rae_loss

def mean_squared_error(true, pred):
    squared_error = np.square(true - pred) 
    sum_squared_error = np.sum(squared_error)
    mse_loss = sum_squared_error / true.size
    return mse_loss

def root_mean_squared_error(true, pred):
    squared_error = np.square(true - pred) 
    sum_squared_error = np.sum(squared_error)
    rmse_loss = np.sqrt(sum_squared_error / true.size)
    return rmse_loss

# %%
# making a prediction
from sklearn.metrics import mean_absolute_error
Y_predicted = model.predict(X_test)

# %%
#evaluating model using the Mean Absolute Error(MAE), Mean Squared Error(MSE) and Root Mean Squared Error(RMSE)
#MSE assesses the quality of a predictor and values closer to zero are better. The goal is to minimize this mean, which will provide us with the best line that goes through all the points.
#RMSE is concerned with deviations from the true values. If the predicted responses are very close to the true responses the RMSE will be small. If the predicted and true responses differ substantially — at least for some observations — the RMSE will be large. A value of zero would indicate a perfect fit to the data.


print("MAE",mean_absolute_error(y_test, Y_predicted))
print("MSE",mean_squared_error(y_test, Y_predicted))
print("RMSE",np.sqrt(mean_squared_error(y_test, Y_predicted)))
# Out:
# MAE 56.617913941058035
# MSE 14006.320510578895
# RMSE 118.34830168016309

# %%
from sklearn.metrics import r2_score
print("R_Squared="), r2_score(y_test, Y_predicted)
# Out:
# R_Squared=
# (None, 0.35642255599195993)

# %%
#The R-squared above is 0.356=35.6%. This means that the model only accounts for about 36% of the variation in the data. 
.
