# %% [markdown]
# # Living room temp data collection: 1 hour test, 1225 data points.

# %% [markdown]
# 12/4/2021 Saturday

# %%
import pandas as pd

# %%
temp_f = pd.read_csv("/Users/andrewlynford/PycharmProjects/arduino/src/project_3/living_room_temp/living_room_temp_1_hour.csv")

# %%
temp_f.head(25)
# Out:
#     sensor   voltage   celsius   fahrenheit
# 0    140.0     18.36     65.05          NaN
# 1    140.0      0.68     18.36        65.05
# 2    140.0      0.68     18.36        65.05
# 3    140.0      0.68     18.36        65.05
# 4    140.0      0.68     18.36        65.05
# 5    140.0      0.68     18.36        65.05
# 6    141.0      0.69     18.85        65.93
# 7    140.0      0.68     18.36        65.05
# 8    140.0      0.68     18.36        65.05
# 9    140.0      0.68     18.36        65.05
# 10   140.0      0.68     18.36        65.05
# 11   140.0      0.68     18.36        65.05
# 12   140.0      0.68     18.36        65.05
# 13   140.0      0.68     18.36        65.05
# 14   140.0      0.68     18.36        65.05
# 15   140.0      0.68     18.36        65.05
# 16   140.0      0.68     18.36        65.05
# 17   140.0      0.68     18.36        65.05
# 18   140.0      0.68     18.36        65.05
# 19   140.0      0.68     18.36        65.05
# ...

# %%
temp_f.plot(figsize=(25,10))
temp_f.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  Notes:
# 1) A voltage drop occured when the board was first being powered up.
#
# 2) The program only ran for 1,225 out of 3,600 seconds and collected 1225 data points.
#
# 3) The Arduino test was conducted for over 1 hour of time; the first location was in front of the window.
#
# 4) The second location was on top of the coffee table in the same room.
#
# 5) The living room thermostat read 72 degrees F during the experiment.
#
# 6) I checked the computer several times throughout the hour to make sure it was not fully in sleep mode.
#
# 7) Clearly this did not work, because the serial monitor appeared to continusly counting when I touched the mouse to activate the screen.
