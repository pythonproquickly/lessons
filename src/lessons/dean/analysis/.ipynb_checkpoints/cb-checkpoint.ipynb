# %%
import pandas as pd
cb = pd.read_csv('./children_books.csv')

# %%
cb
# Out:
#                             Title  \
# 0     The Girl Who Drank the Moon
# 1                 Time Between Us
# 2               Girl Out of Water
# 3                         Captive
# 4             The School of Music
# ...                           ...
# 3264   Spy for the Queen of Scots
# 3265              Jimmy Corrigan:
# 3266             The Martian Girl
# 3267              Buffalo Soldier
# 3268                  Witchstruck
#
#                                                  Author  \
# 0                                        Kelly Barnhill
# 1                                  Tamara Ireland Stone
# 2                                         Nat Luurtsema
# 3                                          A J Grainger
# 4     Rachel Bowen and Meurig Bowen Illustrator: Dan...
# ...                                                 ...
# 3264                                    Theresa Breslin
# 3265                                         Chris Ware
# ...

# %%
min_age = cb['Inerest_age'].str[:2].replace("+", "")#.astype('Int64')
reading_age = cb['Reading_age'].str[:2].replace("+", "")#.astype('Int64')

# %%
display(min_age.to_string())
# Out:
# '0       10\n1       13\n2       13\n3       13\n4       10\n5       12\n6       14\n7       13\n8       12\n9       13\n10      13\n11      13\n12      11\n13      14\n14      11\n15      13\n16      8+\n17      12\n18      14\n19      10\n20      11\n21      14\n22      9+\n23      12\n24      9+\n25      9+\n26      13\n27      7+\n28      12\n29      13\n30      11\n31      13\n32      12\n33      14\n34      10\n35      13\n36      12\n37      10\n38      13\n39      13\n40      13\n41      10\n42      12\n43      14\n44      13\n45      12\n46      13\n47      13\n48      13\n49      11\n50      14\n51      11\n52      13\n53      8+\n54      12\n55      14\n56      10\n57      11\n58      14\n59      9+\n60      12\n61      9+\n62      9+\n63      13\n64      7+\n65      12\n66      13\n67      11\n68      13\n69      12\n70      14\n71      10\n72      13\n73      12\n74      10\n75      13\n76      13\n77      13\n78      10\n79      12\n80      14\n81      13\n82      12\n8
# ...

# %%
reading_age
# Out:
# 0       10
# 1       12
# 2       10
# 3       13
# 4       10
#         ..
# 3264    12
# 3265    14
# 3266    10
# 3267    11
# 3268    12
# Name: Reading_age, Length: 3269, dtype: object

# %%
cb.loc[cb['reading_age'] > 10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reading_age'
#
# ...
