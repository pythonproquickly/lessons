# %%
import pandas as pd
hd = pd.read_csv('./Hobby_Data.csv')

# %%
hd
# Out:
#      Olympiad_Participation Scholarship School       Fav_sub Projects  \
# 0                       Yes         Yes    Yes   Mathematics      Yes
# 1                       Yes         Yes    Yes   Mathematics      Yes
# 2                       Yes         Yes    Yes       Science      Yes
# 3                       Yes         Yes    Yes   Mathematics      Yes
# 4                       Yes         Yes    Yes       Science      Yes
# ...                     ...         ...    ...           ...      ...
# 1596                     No          No    Yes       Science       No
# 1597                    Yes          No    Yes  Any language      Yes
# 1598                    Yes          No    Yes  Any language       No
# 1599                    Yes         Yes    Yes  Any language       No
# 1600                    Yes          No     No   Mathematics      Yes
#
#       Grasp_pow  Time_sprt Medals Career_sprt Act_sprt Fant_arts Won_arts  \
# ...

# %%
hobbies.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 12 entries, ('Any language', 'Academics') to ('Science', 'Sports')
# Series name: Predicted Hobby
# Non-Null Count  Dtype
# --------------  -----
# 12 non-null     int64
# dtypes: int64(1)
# memory usage: 468.0+ bytes

# %%
hobbies.describe()
# Out:
# count     12.000000
# mean     133.416667
# std       85.692323
# min       33.000000
# 25%       81.000000
# 50%      103.500000
# 75%      185.750000
# max      285.000000
# Name: Predicted Hobby, dtype: float64

# %%
hobbies = hd.groupby(["Fav_sub", "Predicted Hobby"])["Predicted Hobby"].count()

# %%
hobbies
# Out:
# Fav_sub            Predicted Hobby
# Any language       Academics          101
#                    Arts                96
#                    Sports              91
# History/Geography  Academics           51
#                    Arts                34
#                    Sports              33
# Mathematics        Academics          285
#                    Arts               174
#                    Sports             221
# Science            Academics          262
#                    Arts               106
#                    Sports             147
# Name: Predicted Hobby, dtype: int64
