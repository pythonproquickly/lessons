# %%
import pandas as pd
cb = pd.read_csv('./children_books.csv')

# %%
cb
# Out:
#                             Title  \
# 0     The Girl Who Drank the Moon
# 1                 Time Between Us
# 2               Girl Out of Water
# 3                         Captive
# 4             The School of Music
# ...                           ...
# 3264   Spy for the Queen of Scots
# 3265              Jimmy Corrigan:
# 3266             The Martian Girl
# 3267              Buffalo Soldier
# 3268                  Witchstruck
#
#                                                  Author  \
# 0                                        Kelly Barnhill
# 1                                  Tamara Ireland Stone
# 2                                         Nat Luurtsema
# 3                                          A J Grainger
# 4     Rachel Bowen and Meurig Bowen Illustrator: Dan...
# ...                                                 ...
# 3264                                    Theresa Breslin
# 3265                                         Chris Ware
# ...

# %%
cb['Inerest_age'] = cb['Inerest_age'].astype("string")
cb['Reading_age'] = cb['Reading_age'].astype("string")
cb['min_age'] = cb['Inerest_age'].str[:2].replace("+", "")
cb['min_age'] = cb['min_age'].astype('Int64')
cb['reading_age'] = cb['Reading_age'].str[:2].replace("+", "")
cb['reading_age'] = cb['reading_age'].astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [41], in <cell line: 4>()
#       2 cb['Reading_age'] = cb['Reading_age'].astype("string")
#       3 cb['min_age'] = cb['Inerest_age'].str[:2].replace("+", "")
# ----> 4 cb['min_age'] = cb['min_age'].astype('Int64')
#       5 cb['reading_age'] = cb['Reading_age'].str[:2].replace("+", "")
#       6 cb['reading_age'] = cb['reading_age'].astype('Int64')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
cb
# Out:
#                             Title  \
# 0     The Girl Who Drank the Moon
# 1                 Time Between Us
# 2               Girl Out of Water
# 3                         Captive
# 4             The School of Music
# ...                           ...
# 3264   Spy for the Queen of Scots
# 3265              Jimmy Corrigan:
# 3266             The Martian Girl
# 3267              Buffalo Soldier
# 3268                  Witchstruck
#
#                                                  Author  \
# 0                                        Kelly Barnhill
# 1                                  Tamara Ireland Stone
# 2                                         Nat Luurtsema
# 3                                          A J Grainger
# 4     Rachel Bowen and Meurig Bowen Illustrator: Dan...
# ...                                                 ...
# 3264                                    Theresa Breslin
# 3265                                         Chris Ware
# ...

# %%
reading_age
# Out:
# 0       10
# 1       12
# 2       10
# 3       13
# 4       10
#         ..
# 3264    12
# 3265    14
# 3266    10
# 3267    11
# 3268    12
# Name: Reading_age, Length: 3269, dtype: object

# %%
cb.loc[cb['reading_age'] > 10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lessons/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reading_age'
#
# ...
